# %%
import mysql.connector
from mysql.connector import errorcode
import pandas as pd

try:
    # Conectar a la base de datos
    cnx = mysql.connector.connect(
        host="localhost",      # Cambia si usas un servidor remoto
        user="root",           # Asegúrate de usar el usuario correcto
        password="AlumnaAdalab",
        database = 'northwind',  
    )

    # Verificar si la conexión está activa
    if cnx.is_connected():
        print("✅ Conexión exitosa")
        mycursor = cnx.cursor()
        print("✅ Cursor creado correctamente")
        print ('Base de datos conectada')
        
    
except mysql.connector.Error as err:
    print(f"❌ Error de conexión: {err}")
# Out:
# ✅ Conexión exitosa
# ✅ Cursor creado correctamente
# Base de datos conectada

# %% [markdown]
# Information.schema, tabla customers : nombres columnas
#
# SELECT * FROM information_schema.COLUMNS WHERE TABLE_NAME and table_schema

# %%
mycursor.execute("USE northwind;")

# %%
query = """SELECT * 
                FROM information_schema.COLUMNS
                WHERE 'customers'
                AND 'northwind'"""

# %%
mycursor.execute (query)

# %%
mycursor.fetchall()
# Out:
# []

# %% [markdown]
# SELECCIONAR TODO DE LA TABLA CUSTOMERS DONDE CITY SEA LONDON O SEATTLE. ALMACENAR LOS RESULTADOS EN UNA VARIABLE

# %%
mycursor.execute("USE northwind;")

# %%
query_city = """SELECT * 
                FROM Customers
                WHERE city ='London' OR city ='Seattle'"""

# %%
mycursor.execute (query_city)

# %%
resultados = mycursor.fetchall()

# %%
print (resultados)
# Out:
# [('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'), ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None), ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Sales Representative', 'Berkeley Gardens 12  Brewery', 'London', None, 'WX1 6LT', 'UK', '(171) 555-2282', '(171) 555-9199'), ('EASTC', 'Eastern Connection', 'Ann Devon', 'Sales Agent', '35 King George', 'London', None, 'WX3 6FW', 'UK', '(171) 555-0297', '(171) 555-3373'), ('NORTS', 'North/South', 'Simon Crowther', 'Sales Associate', 'South House 300 Queensbridge', 'London', None, 'SW7 1RZ', 'UK', '(171) 555-7733', '(171) 555-2530'), ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646'), ('WHITC', 'White Clover Markets', 'Karl Jab
# ...

# %%
df_pais = pd.DataFrame (resultados, columns =['ID_cliente', 'Empresa', 'Nombre_representante', 'Puesto_representante',
                                        'Dirección', 'Ciudad', 'Región', 'Código_postar', 'País', 'Teléfono', 'Fax'])

# %%
df_pais
# Out:
#   ID_cliente                Empresa Nombre_representante  \
# 0      AROUT        Around the Horn         Thomas Hardy
# 1      BSBEV          B's Beverages    Victoria Ashworth
# 2      CONSH  Consolidated Holdings      Elizabeth Brown
# 3      EASTC     Eastern Connection            Ann Devon
# 4      NORTS            North/South       Simon Crowther
# 5      SEVES     Seven Seas Imports           Hari Kumar
# 6      WHITC   White Clover Markets       Karl Jablonski
#
#    Puesto_representante                     Dirección   Ciudad Región  \
# 0  Sales Representative               120 Hanover Sq.   London   None
# 1  Sales Representative             Fauntleroy Circus   London   None
# 2  Sales Representative  Berkeley Gardens 12  Brewery   London   None
# 3           Sales Agent                35 King George   London   None
# 4       Sales Associate  South House 300 Queensbridge   London   None
# 5         Sales Manager               90 Wadhurst Rd.   London   None
# ...

# %% [markdown]
# Otra manera del ejercicio en el que no hay que escribir de manera manual el nombre de las columnas

# %%
column_names = [col[0] for col in mycursor.description] 
df_pais = pd.DataFrame(resultados,columns=column_names)

# %%
df_pais
# Out:
#   CustomerID            CompanyName        ContactName          ContactTitle  \
# 0      AROUT        Around the Horn       Thomas Hardy  Sales Representative
# 1      BSBEV          B's Beverages  Victoria Ashworth  Sales Representative
# 2      CONSH  Consolidated Holdings    Elizabeth Brown  Sales Representative
# 3      EASTC     Eastern Connection          Ann Devon           Sales Agent
# 4      NORTS            North/South     Simon Crowther       Sales Associate
# 5      SEVES     Seven Seas Imports         Hari Kumar         Sales Manager
# 6      WHITC   White Clover Markets     Karl Jablonski                 Owner
#
#                         Address     City Region PostalCode Country  \
# 0               120 Hanover Sq.   London   None    WA1 1DP      UK
# 1             Fauntleroy Circus   London   None    EC2 5NT      UK
# 2  Berkeley Gardens 12  Brewery   London   None    WX1 6LT      UK
# 3                35 King George   London   None    WX3 6FW      UK
# ...

# %% [markdown]
# .

# %%
df_pais.head (3)
# Out:
#   CustomerID            CompanyName        ContactName          ContactTitle  \
# 0      AROUT        Around the Horn       Thomas Hardy  Sales Representative
# 1      BSBEV          B's Beverages  Victoria Ashworth  Sales Representative
# 2      CONSH  Consolidated Holdings    Elizabeth Brown  Sales Representative
#
#                         Address    City Region PostalCode Country  \
# 0               120 Hanover Sq.  London   None    WA1 1DP      UK
# 1             Fauntleroy Circus  London   None    EC2 5NT      UK
# 2  Berkeley Gardens 12  Brewery  London   None    WX1 6LT      UK
#
#             Phone             Fax
# 0  (171) 555-7788  (171) 555-6750
# 1  (171) 555-1212            None
# 2  (171) 555-2282  (171) 555-9199

# %%
df_pais.tail (3)
# Out:
#   CustomerID           CompanyName     ContactName     ContactTitle  \
# 4      NORTS           North/South  Simon Crowther  Sales Associate
# 5      SEVES    Seven Seas Imports      Hari Kumar    Sales Manager
# 6      WHITC  White Clover Markets  Karl Jablonski            Owner
#
#                         Address     City Region PostalCode Country  \
# 4  South House 300 Queensbridge   London   None    SW7 1RZ      UK
# 5               90 Wadhurst Rd.   London   None   OX15 4NB      UK
# 6   305 - 14th Ave. S. Suite 3B  Seattle     WA      98128     USA
#
#             Phone             Fax
# 4  (171) 555-7733  (171) 555-2530
# 5  (171) 555-1717  (171) 555-5646
# 6  (206) 555-4112  (206) 555-4115

# %%
df_pais.sample (2)
# Out:
#   CustomerID           CompanyName     ContactName          ContactTitle  \
# 6      WHITC  White Clover Markets  Karl Jablonski                 Owner
# 0      AROUT       Around the Horn    Thomas Hardy  Sales Representative
#
#                        Address     City Region PostalCode Country  \
# 6  305 - 14th Ave. S. Suite 3B  Seattle     WA      98128     USA
# 0              120 Hanover Sq.   London   None    WA1 1DP      UK
#
#             Phone             Fax
# 6  (206) 555-4112  (206) 555-4115
# 0  (171) 555-7788  (171) 555-6750

# %% [markdown]
# Valores nulos

# %%
df_pais.isna().sum()
# Out:
# CustomerID      0
# CompanyName     0
# ContactName     0
# ContactTitle    0
# Address         0
# City            0
# Region          6
# PostalCode      0
# Country         0
# Phone           0
# Fax             1
# dtype: int64

# %% [markdown]
# Muestra los principales estadísticos:

# %%
df_pais.describe().T
# Out:
#              count unique                   top freq
# CustomerID       7      7                 AROUT    1
# CompanyName      7      7       Around the Horn    1
# ContactName      7      7          Thomas Hardy    1
# ContactTitle     7      5  Sales Representative    3
# Address          7      7       120 Hanover Sq.    1
# City             7      2                London    6
# Region           1      1                    WA    1
# PostalCode       7      7               WA1 1DP    1
# Country          7      2                    UK    6
# Phone            7      7        (171) 555-7788    1
# Fax              6      6        (171) 555-6750    1

# %% [markdown]
# Muestra el nombre de las columnas del Dataframe:

# %%
df_pais.columns
# Out:
# Index(['CustomerID', 'CompanyName', 'ContactName', 'ContactTitle', 'Address',
#        'City', 'Region', 'PostalCode', 'Country', 'Phone', 'Fax'],
#       dtype='object')
